# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import unittest

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

plt.rcParams.update({'font.size': 14})
np.random.seed(42)
test = unittest.TestCase()

# %%
import sklearn.datasets
import warnings

# Load data we'll work with - Boston housing dataset
# We'll use sklearn's built-in data
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    
    ds_boston = sklearn.datasets.load_boston()

feature_names = list(ds_boston.feature_names)

n_features = len(feature_names)
x, y = ds_boston.data, ds_boston.target
n_samples = len(y)
print(f'Loaded {n_samples} samples')
# Out:
# Loaded 506 samples

# %%
# Load into a pandas dataframe and show some samples
df_boston = pd.DataFrame(data=x, columns=ds_boston.feature_names)
df_boston = df_boston.assign(MEDV=y)
df_boston.head(10).style.background_gradient(subset=['MEDV'], high=1.)
# Out:
# <style type="text/css">
# #T_42748_row0_col13 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_42748_row1_col13 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_42748_row2_col13 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_42748_row3_col13 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_42748_row4_col13 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_42748_row5_col13 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_42748_row6_col13 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_42748_row7_col13 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_42748_row8_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_42748_row9_col13 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# </style>
# <table id="T_42748">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42748_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_42748_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_42748_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_42748_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_42748_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_42748_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_42748_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_42748_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_42748_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_42748_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_42748_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_42748_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_42748_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_42748_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42748_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42748_row0_col0" class="data row0 col0" >0.006320</td>
#       <td id="T_42748_row0_col1" class="data row0 col1" >18.000000</td>
#       <td id="T_42748_row0_col2" class="data row0 col2" >2.310000</td>
#       <td id="T_42748_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_42748_row0_col4" class="data row0 col4" >0.538000</td>
#       <td id="T_42748_row0_col5" class="data row0 col5" >6.575000</td>
#       <td id="T_42748_row0_col6" class="data row0 col6" >65.200000</td>
#       <td id="T_42748_row0_col7" class="data row0 col7" >4.090000</td>
#       <td id="T_42748_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_42748_row0_col9" class="data row0 col9" >296.000000</td>
#       <td id="T_42748_row0_col10" class="data row0 col10" >15.300000</td>
#       <td id="T_42748_row0_col11" class="data row0 col11" >396.900000</td>
#       <td id="T_42748_row0_col12" class="data row0 col12" >4.980000</td>
#       <td id="T_42748_row0_col13" class="data row0 col13" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42748_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_42748_row1_col0" class="data row1 col0" >0.027310</td>
#       <td id="T_42748_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_42748_row1_col2" class="data row1 col2" >7.070000</td>
#       <td id="T_42748_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_42748_row1_col4" class="data row1 col4" >0.469000</td>
#       <td id="T_42748_row1_col5" class="data row1 col5" >6.421000</td>
#       <td id="T_42748_row1_col6" class="data row1 col6" >78.900000</td>
#       <td id="T_42748_row1_col7" class="data row1 col7" >4.967100</td>
#       <td id="T_42748_row1_col8" class="data row1 col8" >2.000000</td>
#       <td id="T_42748_row1_col9" class="data row1 col9" >242.000000</td>
#       <td id="T_42748_row1_col10" class="data row1 col10" >17.800000</td>
#       <td id="T_42748_row1_col11" class="data row1 col11" >396.900000</td>
#       <td id="T_42748_row1_col12" class="data row1 col12" >9.140000</td>
#       <td id="T_42748_row1_col13" class="data row1 col13" >21.600000</td>
#     </tr>
#     <tr>
#       <th id="T_42748_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_42748_row2_col0" class="data row2 col0" >0.027290</td>
#       <td id="T_42748_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_42748_row2_col2" class="data row2 col2" >7.070000</td>
#       <td id="T_42748_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_42748_row2_col4" class="data row2 col4" >0.469000</td>
#       <td id="T_42748_row2_col5" class="data row2 col5" >7.185000</td>
#       <td id="T_42748_row2_col6" class="data row2 col6" >61.100000</td>
#       <td id="T_42748_row2_col7" class="data row2 col7" >4.967100</td>
#       <td id="T_42748_row2_col8" class="data row2 col8" >2.000000</td>
#       <td id="T_42748_row2_col9" class="data row2 col9" >242.000000</td>
#       <td id="T_42748_row2_col10" class="data row2 col10" >17.800000</td>
#       <td id="T_42748_row2_col11" class="data row2 col11" >392.830000</td>
#       <td id="T_42748_row2_col12" class="data row2 col12" >4.030000</td>
#       <td id="T_42748_row2_col13" class="data row2 col13" >34.700000</td>
#     </tr>
#     <tr>
#       <th id="T_42748_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_42748_row3_col0" class="data row3 col0" >0.032370</td>
#       <td id="T_42748_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_42748_row3_col2" class="data row3 col2" >2.180000</td>
#       <td id="T_42748_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_42748_row3_col4" class="data row3 col4" >0.458000</td>
#       <td id="T_42748_row3_col5" class="data row3 col5" >6.998000</td>
#       <td id="T_42748_row3_col6" class="data row3 col6" >45.800000</td>
#       <td id="T_42748_row3_col7" class="data row3 col7" >6.062200</td>
#       <td id="T_42748_row3_col8" class="data row3 col8" >3.000000</td>
#       <td id="T_42748_row3_col9" class="data row3 col9" >222.000000</td>
#       <td id="T_42748_row3_col10" class="data row3 col10" >18.700000</td>
#       <td id="T_42748_row3_col11" class="data row3 col11" >394.630000</td>
#       <td id="T_42748_row3_col12" class="data row3 col12" >2.940000</td>
#       <td id="T_42748_row3_col13" class="data row3 col13" >33.400000</td>
#     </tr>
#     <tr>
#       <th id="T_42748_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_42748_row4_col0" class="data row4 col0" >0.069050</td>
#       <td id="T_42748_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_42748_row4_col2" class="data row4 col2" >2.180000</td>
#       <td id="T_42748_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_42748_row4_col4" class="data row4 col4" >0.458000</td>
#       <td id="T_42748_row4_col5" class="data row4 col5" >7.147000</td>
#       <td id="T_42748_row4_col6" class="data row4 col6" >54.200000</td>
#       <td id="T_42748_row4_col7" class="data row4 col7" >6.062200</td>
#       <td id="T_42748_row4_col8" class="data row4 col8" >3.000000</td>
#       <td id="T_42748_row4_col9" class="data row4 col9" >222.000000</td>
#       <td id="T_42748_row4_col10" class="data row4 col10" >18.700000</td>
#       <td id="T_42748_row4_col11" class="data row4 col11" >396.900000</td>
#       <td id="T_42748_row4_col12" class="data row4 col12" >5.330000</td>
#       <td id="T_42748_row4_col13" class="data row4 col13" >36.200000</td>
#     </tr>
#     <tr>
#       <th id="T_42748_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_42748_row5_col0" class="data row5 col0" >0.029850</td>
#       <td id="T_42748_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_42748_row5_col2" class="data row5 col2" >2.180000</td>
#       <td id="T_42748_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_42748_row5_col4" class="data row5 col4" >0.458000</td>
#       <td id="T_42748_row5_col5" class="data row5 col5" >6.430000</td>
#       <td id="T_42748_r

# %%
df_boston.loc[:, df_boston.columns != 'MEDV' ].corrwith(df_boston['MEDV']).sort_values(key=abs, ascending=False)
# Out:
# LSTAT     -0.737663
# RM         0.695360
# PTRATIO   -0.507787
# INDUS     -0.483725
# TAX       -0.468536
# NOX       -0.427321
# CRIM      -0.388305
# RAD       -0.381626
# AGE       -0.376955
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# dtype: float64

# %%
df_boston[['LSTAT', 'RM', 'MEDV']]
# Out:
#      LSTAT     RM  MEDV
# 0     4.98  6.575  24.0
# 1     9.14  6.421  21.6
# 2     4.03  7.185  34.7
# 3     2.94  6.998  33.4
# 4     5.33  7.147  36.2
# ..     ...    ...   ...
# 501   9.67  6.593  22.4
# 502   9.08  6.120  20.6
# 503   5.64  6.976  23.9
# 504   6.48  6.794  22.0
# 505   7.88  6.030  11.9
#
# [506 rows x 3 columns]
